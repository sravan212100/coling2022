# %%
import pandas as pd

# %%
train = pd.read_csv('task5_train_user_wlabel.tsv', sep='\t')
valid = pd.read_csv('task5_validation_user_NOlabel.tsv', sep='\t')
test = pd.read_csv('task5_test_user_NOlabel.tsv', sep='\t')
# print(train.label.nunique())
# print(train.label.unique())
train
# Out:
#        tweet_id                                         tweet_text  \
# 0        103856  Un estudio demuestra que los niños pueden ser ...
# 1        102562  Los pacientes y contactos asintomáticos pueden...
# 2        104842  Establecen en Gaceta Oficial baremos de costos...
# 3        101461  🎶 David Catá homenajea con un vídeo musical a ...
# 4        102771  Aprueban condonar dos meses de renta comercian...
# ...         ...                                                ...
# 10046    105449  ¡ESTEMOS ALERTAS!desde el Comité de Emergencia...
# 10047    102401  Advierten que personas con coronavirus o en cu...
# 10048    300333  Informe covid día 3: me ha agarrado harto el o...
# 10049    100090  Esta es la razón por la que la COVID-19 hace q...
# 10050    100622  Lineamiento médico sugerido para pacientes con...
#
#                       label
# 0         Lit-News_mentions
# 1         Lit-News_mentions
# 2         Lit-News_mentions
# 3         Lit-News_mentions
# 4         Lit-News_mentions
# ...                     ...
# 10046     Lit-News_mentions
# 10047     Lit-News_mentions
# 10048  non-personal_reports
# 10049     Lit-News_mentions
# 10050     Lit-News_mentions
#
# [10051 rows x 3 columns]

# %%
pd.concat([valid,test]).to_csv('test.tsv', sep='\t')
test = pd.read_csv('test.tsv', sep='\t')
test = test.drop('Unnamed: 0',axis=1)
test
# Out:
#        tweet_id                                         tweet_text
# 0        107883  Muy preocupau con la noticia. Doblegar la curv...
# 1        107720  @MoChao33 @carmenvivomivid @SalvaGarca4 @Hondo...
# 2        107268  Si ha sido vacunado contra el #COVID19 y prese...
# 3        302934  Las vacunas 3 y hablamos inminidad vivo ➡️ Son...
# 4        302479  Hola @Liberbank ! ¿Puedo solicitar la línea de...
# ...         ...                                                ...
# 10422    202689  Me van a odiar en mi trabajo, soy quien los va...
# 10423    110180  Estudian medicamentos senolíticos como alterna...
# 10424    109203  Lourdes Vázquez explica a NNGG-LB los efectos ...
# 10425    203260  Yo todavía me estoy riendo. Que pasa con @abc_...
# 10426    202769  Como me falta la respiración nose si es porque...
#
# [10427 rows x 2 columns]

# %%
train.label.value_counts()
# Out:
# Lit-News_mentions       5984
# non-personal_reports    2413
# Self_reports            1654
# Name: label, dtype: int64

# %% [markdown]
# # 5 fold

# %%
size = len(train.label)
for i in range(5):
    train[int(i*0.2*size):int((i+1)*0.2*size)].to_csv('validation_{}.tsv'.format(i), sep='\t')
    train.drop(list(range(int(i*0.2*size),int((i+1)*0.2*size)))).to_csv('train_{}.tsv'.format(i), sep='\t')

# %% [markdown]
# # pseudo

# %%
pred = pd.read_csv('result.tsv', sep='\t')
pseudo = pd.concat([pred,train]).sample(frac=1)
pseudo
# Out:
#       tweet_id                                         tweet_text  \
# 4907    202945  Busco alguien que me de una explicación... per...
# 1633    105716  Las OSCs cuentan con información que debe ser ...
# 4967    200231  @Orapixel Joder Geometry dash facebook me día ...
# 2143    302392  GRACIAS. He salido a sacar a mi perro y una se...
# 1028    201178  Mire señora resulta q soy bastante exigente co...
# ...        ...                                                ...
# 1997    109188  Sin desperdicio COVID-19 Los invito a darse el...
# 4636    105946  Algunos pacientes recuperados del covid-19 pod...
# 6792    301977  Al igual que otras enfermedades respiratorias ...
# 6672    200642  mi abuela acaba de decir que dios nos sana????...
# 6485    101873  Evidencia reciente indica que el COVID-19 atac...
#
#                      label
# 4907          Self_reports
# 1633     Lit-News_mentions
# 4967          Self_reports
# 2143  non-personal_reports
# 1028          Self_reports
# ...                    ...
# 1997     Lit-News_mentions
# 4636     Lit-News_mentions
# 6792  non-personal_reports
# 6672          Self_reports
# 6485     Lit-News_mentions
#
# [16901 rows x 3 columns]

# %%
pseudo.to_csv('pseudo.tsv', sep='\t')
pseudo = pd.read_csv('pseudo.tsv', sep='\t')
pseudo = pseudo.drop('Unnamed: 0',axis=1)

# %%
size = len(pseudo.label)
for i in range(5):
    pseudo[int(i*0.2*size):int((i+1)*0.2*size)].to_csv('validation_{}.tsv'.format(i), sep='\t')
    pseudo.drop(list(range(int(i*0.2*size),int((i+1)*0.2*size)))).to_csv('train_{}.tsv'.format(i), sep='\t')
